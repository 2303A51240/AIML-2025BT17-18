# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51240/AIML-2025BT17-18/blob/main/aiml2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

list1 = [1, 2, 3, 4]
list2 = [5, 6, 7, 8]


array1 = np.array([1, 2, 3, 4])
array2 = np.array([5, 6, 7, 8])


print(type(list1))
print(type(array1))


print(array1 * array2)


print(array1 / array2)


print(array1 ** 2)


result = array1 + array2
print("Addition of Two: array1 + array2 = ", result)


print(np.sin(array1))
print(np.log(array1))
print(np.log2(array1))
print(np.exp(array1))
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>
# [ 5 12 21 32]
# [0.2        0.33333333 0.42857143 0.5       ]
# [ 1  4  9 16]
# Addition of Two: array1 + array2 =  [ 6  8 10 12]
# [ 0.84147098  0.90929743  0.14112001 -0.7568025 ]
# [0.         0.69314718 1.09861229 1.38629436]
# [0.        1.        1.5849625 2.       ]
# [ 2.71828183  7.3890561  20.08553692 54.59815003]

# %%
# prompt: Generate a Data set for Health Care using the following:
# people = [’kiran’, arun’, ’vijay’, ’varun’]
# age =[25, 30, 35, 40, 45]
# height =[145, 151, 165, 173]
# weight=[45, 55, 65, 75]
# 2. Using the generated dataset given above. Generate the following graphs and justify the
# relationships among the vectors.
# 3. Scatter Plot
# 4. Bar Chart
# 5. Histogram
# 6. Provide Graph Title, labels for X, Y axis with prope

import matplotlib.pyplot as plt

people = ['kiran', 'arun', 'vijay', 'varun']
age =[25, 30, 35, 40]
height =[145, 151, 165, 173]
weight=[45, 55, 65, 75]

# Scatter Plot
plt.figure(figsize=(8, 6))
plt.scatter(age, weight, s=80)
plt.title("Relationship between Age and Weight")
plt.xlabel("Age")
plt.ylabel("Weight (kg)")
plt.grid(True)
plt.show()
# This scatter plot can help visualize if there's a correlation between age and weight.
# For instance, does weight tend to increase with age in this group?

# Bar Chart
plt.figure(figsize=(10, 6))
plt.bar(people, height)
plt.title("Height Comparison")
plt.xlabel("People")
plt.ylabel("Height (cm)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# This bar chart provides a clear comparison of heights among the individuals.

# Histogram
plt.figure(figsize=(8, 6))
plt.hist(age, bins=5, edgecolor='black')
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()
# This histogram shows the distribution of ages within the group.
# It can reveal if the ages are concentrated within a certain range or spread out.
